# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
def labelling(exa,label):
  #returns labelled set
  if label==1:
    exa['label'] = np.ones(len(exa))
  elif label ==0:
    exa['label'] = np.zeros(len(exa))
  return exa

# %%
P0 = np.load('P0.npy')
P1 = np.load('P1.npy')

# %%
P0 = pd.DataFrame(P0).T
P1 = pd.DataFrame(P1).T

P0=labelling(P0,0)
P1=labelling(P1,1)

# %%
result = pd.concat([P0,P1], ignore_index=True)

# %%
result.columns = ['x','y', 'label']

# %%
result
# Out:
#                x         y  label
# 0       0.926612  4.717092    0.0
# 1      -3.953953  1.274478    0.0
# 2      -7.161693 -0.984415    0.0
# 3      -0.956840  1.115828    0.0
# 4      -0.046090  2.083444    0.0
# 5      -0.781831  1.760140    0.0
# 6       4.823815  5.671658    0.0
# 7      -1.475902  3.410829    0.0
# 8       2.547051  3.721362    0.0
# 9      -0.383767  3.075622    0.0
# 10     -1.716112  0.634044    0.0
# 11      3.288619  4.627408    0.0
# 12     -2.314298  3.202437    0.0
# 13      6.468557  5.775499    0.0
# 14      1.467048  4.542046    0.0
# 15     -1.592415  0.987353    0.0
# 16     -3.070221  2.846598    0.0
# 17      2.007895  4.298266    0.0
# 18     -2.428834  1.441157    0.0
# 19     -3.512497  0.382466    0.0
# 20      2.324787  4.591678    0.0
# 21     -0.277727  1.011448    0.0
# 22     -1.224092  2.336990    0.0
# 23      0.283878  3.387220    0.0
# 24      2.924644  4.848619    0.0
# 25     -3.201400 -0.230598    0.0
# 26      1.593172  4.198276    0.0
# 27     -3.164014  1.212106    0.0
# 28      1.667765  5.931186    0.0
# 29      6.965631  9.399394    0.0
# ...          ...       ...    ...
# 19970   0.882812 -0.922781    1.0
# 19971   9.656033  5.404631    1.0
# 19972   4.074257  4.273174    1.0
# 19973   3.815676  1.670100    1.0
# 19974  11.587388  6.142501    1.0
# 19975   7.241222  3.111752    1.0
# 19976   0.556421 -1.346005    1.0
# 19977   7.882867  5.335528    1.0
# 19978   5.980343  0.981304    1.0
# 19979  12.353268  8.154322    1.0
# 19980   8.156419  5.078893    1.0
# 19981   1.151355  2.369958    1.0
# 19982   3.376853  0.593388    1.0
# 19983  -1.694780 -1.064626    1.0
# 19984   8.267957  4.994262    1.0
# 19985   4.642301  2.337674    1.0
# 19986  14.638580  8.145871    1.0
# 19987   2.706790  0.771892    1.0
# 19988   1.978717  1.150782    1.0
# 19989   4.639909  2.357640    1.0
# 19990   0.850923  0.956626    1.0
# 19991   4.430945  3.326172    1.0
# 19992  -0.581654 -1.248981    1.0
# 19993  10.348722  6.616759    1.0
# 19994  10.315759  5.573531    1.0
# 19995   3.604288  2.839583    1.0
# 19996   0.855397 -0.963416    1.0
# 19997   7.416902  4.290466    1.0
# 19998   9.685447  7.290335    1.0
# 19999   9.195642  6.324578    1.0
#
# [20000 rows x 3 columns]

# %%
# compute sigmoid nonlinearity

def sigmoid(x):
    output = 1/(1+np.exp(-x))
    return output

# convert output of sigmoid function to its derivative
def sigmoid_output_to_derivative(output):
    return output*(1-output)

# input dataset
X = result[['x','y']]

y = result['label']

# seed random numbers to make calculation
# deterministic (just a good practice)
np.random.seed(1)

# initialize weights randomly with mean 0

synapse_0 = 2*np.random.random((2,1)) - 1


for iter in range(5):
# forward propagation
    layer_0 = X
    layer_1 = sigmoid(np.dot(layer_0,synapse_0))
    layer_1_error = layer_1 - y

# multiply how much we missed by the
# slope of the sigmoid at the values in l1

    layer_1_delta = layer_1_error * sigmoid_output_to_derivative(layer_1)

    synapse_0_derivative = np.dot(layer_0.T,layer_1_delta)

# update weights

    synapse_0 -= synapse_0_derivative

print("Output After Training:")

print(layer_1)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-18-f89566074492> in <module>()
#      28     layer_0 = X
#      29     layer_1 = sigmoid(np.dot(layer_0,synapse_0))
# ---> 30     layer_1_error = layer_1 - y
#      31
#      32 # multiply how much we missed by the
#
# /home/helena/.local/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     719             index=left.index,
#     720             name=name,
# --> 721             dtype=dtype,
#     722         )
#     723
#
# /home/helena/.local/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in _construct_result(left, result, index, name, dtype)
#     627
#     628 def _construct_result(left, result, index, name, dtype):
# --> 629     return left._constructor(result, index=index, name=name, dtype=dtype)
#     630
#     631
#
# /home/helena/.local/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     239             else:
#     240                 data = _sanitize_array(data, index, dtype, copy,
# --> 241                                        raise_cast_failure=True)
#     242
#     243                 data = SingleBlockManager(data, index, fastpath=True)
#
# /home/helena/.local/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2946     elif subarr.ndim > 1:
#    2947         if isinstance(data, np.ndarray):
# -> 2948             raise Exception('Data must be 1-dimensional')
#    2949         else:
#    2950             subarr = _asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
l2
# Out:
# array([[ 0.51453109],
#        [ 0.52549488],
#        [ 0.47441107],
#        [ 0.48215624]])

# %%
syn1
# Out:
# array([[ 0.1163538 ],
#        [ 0.28668264],
#        [ 0.63960476],
#        [-0.52897531]])

# %%
syn0
# Out:
# array([[-0.22369124, -0.11936918, -0.7932773 ,  0.50012866],
#        [-0.88059673, -0.92066046,  0.03268101, -0.44604978],
#        [ 0.68385397,  0.1965043 , -0.34351112,  0.12415502]])
